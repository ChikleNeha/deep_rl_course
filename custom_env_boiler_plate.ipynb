# %% [markdown]
# <a href="https://colab.research.google.com/github/ChikleNeha/deep_rl_course/blob/main/custom_env_boiler_plate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from getpass import getpass

# Enter your details
user = "ChikleNeha"
password = getpass('Enter your GitHub PAT: ')
repo_name = "my-custom-env"

# Clone your repo (if it's empty, we'll initialize it)
# !git clone https://{user}:{password}@github.com/{user}/{repo_name}.git
# %cd {repo_name}
# Out:
# Enter your GitHub PAT: ··········
# Cloning into 'my-custom-env'...
# ...
# /content/my-custom-env

# %%
# Install copier to generate the template
# !pip install copier
# !copier copy https://github.com/Farama-Foundation/gymnasium-env-template.git .
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.4/127.4 kB 12.9 MB/s eta 0:00:00
# ...
# No git tags found in template; using HEAD as ref
# 🎤 The name of your Gymnasium environment
#    gymnasium_envWARNING: your terminal doesn't support cursor position requests (CPR).
# 🎤 The name of your Gymnasium environment
#    gymnasium_env🎤 The name of your Gymnasium environment
#    gymnasium_envmy_env
# 🎤 The license for your Gymnasium environment
#    (Use arrow keys)
#    GPL-3.0-or-later
#  » MIT
#    Apache-2.0
#    Unlicense
#    NoneWARNING: your terminal doesn't support cursor position requests (CPR).
# 🎤 The license for your Gymnasium environment
#    (Use arrow keys)
#    GPL-3.0-or-later
#  » MIT
#    Apache-2.0
#    Unlicense
#    None🎤 The license for your Gymnasium environment
#    MIT
#
# ...

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/my-custom-env
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.4/226.4 kB 22.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.4/99.4 kB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 136.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 38.0 MB/s eta 0:00:00
# ...
#   Building editable for gymnasium_envmy_env (pyproject.toml) ... done
#   Created wheel for gymnasium_envmy_env: filename=gymnasium_envmy_env-0.0.1-py2.py3-none-any.whl size=1971 sha256=7b8e9baa048894cefb5b3df0d77ac95d041c5e833723db1467653ddc5ecf05f9
# ...

# %%
def sync_to_github(commit_message="Update"):
    # !git config --global user.email "chikleneha473@gmail.com"
    # !git config --global user.name "ChikleNeha"
    # !git add .
    # !git commit -m "{commit_message}"
    # !git push origin main

# Use it like this:
sync_to_github("Boiler plate")
# Out:
# [main (root-commit) a406b5f] Boiler plate
#  13 files changed, 501 insertions(+)
#  create mode 100644 .gitignore
#  create mode 100644 .pre-commit-config.yaml
#  create mode 100644 LICENSE
#  create mode 100644 README.md
#  create mode 100644 gymnasium_envmy_env/__init__.py
#  create mode 100644 gymnasium_envmy_env/envs/__init__.py
#  create mode 100644 gymnasium_envmy_env/envs/grid_world.py
#  create mode 100644 gymnasium_envmy_env/wrappers/__init__.py
#  create mode 100644 gymnasium_envmy_env/wrappers/clip_reward.py
#  create mode 100644 gymnasium_envmy_env/wrappers/discrete_actions.py
#  create mode 100644 gymnasium_envmy_env/wrappers/reacher_weighted_reward.py
#  create mode 100644 gymnasium_envmy_env/wrappers/relative_position.py
#  create mode 100644 pyproject.toml
# Enumerating objects: 18, done.
# Counting objects: 100% (18/18), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (18/18), done.
# ...
