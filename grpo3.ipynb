# %% [markdown]
# <a href="https://colab.research.google.com/github/ChikleNeha/deep_rl_course/blob/main/grpo3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import zipfile
with zipfile.ZipFile('/content/drive/MyDrive/kaizen.zip', 'r') as z:
    z.extractall('/content/')

# %cd /content/kaizen
# Out:
# Mounted at /content/drive
# /content/kaizen

# %%
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install trl datasets accelerate bitsandbytes wandb matplotlib
# Out:
# ...
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-s66tap9r/unsloth_2351070d48fb41638facbdabe6ea27af
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-s66tap9r/unsloth_2351070d48fb41638facbdabe6ea27af
#   Resolved https://github.com/unslothai/unsloth.git to commit 5c473fab80e079bb525345b86cb71afd409262c3
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 17.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 44.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 121.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.9/421.9 kB 43.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 130.0 MB/s eta 0:00:00
# ...

# %%
# !python training/sft_train.py
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# [SFT] ===== Kaizen OS — Supervised Fine-Tuning =====
# [SFT] Model        : unsloth/Qwen2.5-3B-Instruct
# [SFT] LoRA rank    : 16
# [SFT] Batch size   : 2 (effective: 8)
# [SFT] Max steps    : 100
# [SFT] Output dir   : ./kaizen_sft_model
#
# [SFT] Loading base model...
# ==((====))==  Unsloth 2026.4.8: Fast Qwen2 patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors: 100% 2.36G/2.36G [00:18<00:00, 127MB/s]
# Loading weights: 100% 434/434 [00:03<00:00, 118.58it/s]
# ...

# %%
# !python training/grpo_train.py
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# [SandboxExecutor] Running in Simulated mode.
# [GRPO] ===== Kaizen OS — GRPO Reinforcement Learning =====
# [GRPO] SFT model path : ./kaizen_sft_model
# [GRPO] Group size     : 4
# [GRPO] KL coefficient : 0.1
# [GRPO] Learning rate  : 5e-06
# [GRPO] Max steps      : 80
# [GRPO] Output dir     : ./kaizen_grpo_model
# [GRPO] Max new tokens : 256
#
# [GRPO] Loading SFT model...
# ==((====))==  Unsloth 2026.4.8: Fast Qwen2 patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# ...

# %%
import shutil
from google.colab import files
shutil.make_archive('/content/kaizen_grpo_model', 'zip', '/content/kaizen', 'kaizen_grpo_model')
files.download('/content/kaizen_grpo_model.zip')
files.download('/content/kaizen/reward_curve.png')
